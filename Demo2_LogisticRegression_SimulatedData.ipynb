# %% [markdown]
# # UW Data 558 Polished Code Release - Daniel White
# ## Simulated Dataset

# %% [markdown]
# ### Introduction
# This Jupyter notebook demonstrates the use of gradient descent to fit a Logistic Regression model. In this notebook, I will develop my own Logistic Regression algorithm and assess the training process and the performance of the model on a simulated.
#
# The simulated dataset used in this notebook is generated from the sklearn make_classification function. The predictor variables are randomly generated and the response vector contains a binary indicator variable.

# %%
#Change ipython notebook output settings
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#Import packages required packages
import src.LogisticRegression as mlr
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegressionCV
from sklearn.datasets import make_classification

# %% [markdown]
# ### Data Preparation
#
# In the code block below, the dataset is loaded into memory, divided into the predictor (X) and response (Y) sets. The predictor and response sets are then divided into training and test sets. The training set will used to fit the model while the test set will be used to test its performance in correctly classifying emails as spam. The data in the both predictor sets are centered and standardized on the same scale.

# %%
# Create a simulated dataset using sklearn
np.random.seed(9)
X, y = make_classification(n_samples = 1000, n_features = 30, n_classes = 2)

#Replace 0s with -1 in response vector
y[y==0] = -1

#Split into training and test set and standardize data using the sklearn functions

# Create training and test sets for X and Y variables
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# Standardize the data using SKlearn processing
scaler = preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# Append a column of 1's to X_train and X_test to represent the model intercept coefficient
X_train = preprocessing.add_dummy_feature(X_train) 
X_test = preprocessing.add_dummy_feature(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# ### Logistic Regression Model Training
#
# Using the my_logistic_regression function, the model is trained based on the features in the predictor training set and the classification of the response set. The Logistic Regression objective function can be summarized as:
#
# $$\min_{\beta \in \mathbb{R}^d} \: -\frac{1}{n} \sum_{i=1}^n \left(y_i\beta^Tx_i+ \log(1+\exp(x_i^T \beta))\right).$$
#
# The model is first initialized with a random set of coefficients and the objective function is minimized iteratively. The chart below shows the value of the objective value for Logistic Regression through each iteration of the model. The objective value decreases with every iteration until the stopping criteria for the model is reached.

# %%
np.random.seed(9)
n,d = X_train.shape
eps = 0.001
max_iter = 1000
lamb = 1
t_init = mlr.compute_t(X_train, lamb=lamb)
beta_in = np.random.normal(size=d)

#Fit model
mlr_training = mlr.my_logistic_regression(beta_in, X=X_train, Y=y_train, t_init = t_init, eps= eps, max_iter = max_iter, lamb=lamb)

#Plot training process
mlr.plot_training_obj(mlr_training,
                     X=X_train, 
                     Y=y_train, 
                     lamb=lamb, 
                     plot_title = "Logistic Regression Training - Spam Dataset")
# Out:
# /Users/danielwhite/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### Logistic Regression Model Performance

# %% [markdown]
# The performance of the model through each iteration of the training process is depicted in the chart below. At the first iteration, the model has roughly a 55% misclassification rate. The misclassification rate decreases with every iteration as the objective value of the Logistic Regression equation is minimized. For the training depicted below, the regularization parameter (lambda) was set equal to 1. Under this default setting, the misclassification for the training and test set was comparable throughout the training process.

# %%
mlr.plot_training_misclass(mlr_training, 
                          X_train=X_train, 
                          y_train=y_train, 
                          X_test=X_test, 
                          y_test=y_test, 
                          lamb=lamb, 
                          plot_title = "Logistic Regression Training vs. Test Misclassification - Spam Dataset")

# %% [markdown]
# The final model used for classification is the final iteration from the training process. Using this model, the misclassification errors for the training and test sets are computed and presented in the code block below. Overall, the misclassification rates for both dataset are approximately 15-16%.

# %%
train_misclass = lr.class_error(X_train.dot(mlr_training[-1]), y_train)
print("The misclassification error on the training set is", train_misclass)
test_misclass = lr.class_error(X_test.dot(mlr_training[-1]), y_test)
print("The misclassification error on the test set is", test_misclass)
# Out:
# The misclassification error on the training set is 0.150666666667
# The misclassification error on the test set is 0.164

# %% [markdown]
# ### Logistic Regression Model Performance - Cross-validation

# %% [markdown]
# Next, the ideal value for the regularization parameter lambda is computed using the cross-validation function for Logistic Regression from sklearn. The best parameter is transformed to match the objective function used in the analysis and printed below.

# %%
#Use sklearn to compute optimal lambda parameter
logregCV = LogisticRegressionCV()
logregCV_fit = logregCV.fit(X_train, y_train)
best_C = logregCV_fit.C_
n,d = X_train.shape
CV_lamb = 1/(2*n*best_C)
print("According to CV, the optimal lambda parameter is", float(CV_lamb))
# Out:
# According to CV, the optimal lambda parameter is 0.11120670248000393

# %% [markdown]
# In the code block below, the Logistic Regression model is refitted using the regularization parameter computed using cross-validation. As the chart shows, the misclassification error rate is slightly lower on the training set than the test set.

# %%
#Set model settings
np.random.seed(9)
n,d = X_train.shape
eps = 0.001
max_iter = 1000
lamb = CV_lamb
t_init = lr.compute_t(X_train, lamb=lamb)
beta_in = np.random.normal(size=d)

#Fit model
mlr_training = lr.my_logistic_regression(beta_in, X=X_train, Y=y_train, t_init = t_init, eps= eps, max_iter = max_iter, lamb=lamb)

#Plot performance during training process
mlr.plot_training_misclass(mlr_training, 
                          X_train=X_train, 
                          y_train=y_train, 
                          X_test=X_test, 
                          y_test=y_test, 
                          lamb=lamb, 
                          plot_title = "Logistic Regression Training vs. Test Misclassification (CV) - Spam Dataset ")

# %% [markdown]
# The misclassification error rate on the training and test set in the final model are presented below. Overall, the regularization parameter computed by sklearn improved the accuracy of the model with a lower misclassication rate on both the training and test sets.

# %%
train_misclass = lr.class_error(X_train.dot(mlr_training[-1]), y_train)
print("The misclassification error on the training set is", train_misclass)
test_misclass = lr.class_error(X_test.dot(mlr_training[-1]), y_test)
print("The misclassification error on the test set is", test_misclass)
# Out:
# The misclassification error on the training set is 0.14
# The misclassification error on the test set is 0.152
